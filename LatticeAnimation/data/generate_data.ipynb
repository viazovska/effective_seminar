# %%
print "d,c_d"

for i in range(1,exp(5)):
    print (i*1.0).n(),",",(2*(i-1)).n()
    # print 4*i,",",8.8*i

for j in range(10,1600):
    i=exp(j/2)
    print (i*1.0).n(),",",(2*(i-1)).n()
    # print (4*i).n(),",",(8.8*i).n()
# Out:
# d,c_d
# 1.00000000000000 , 0.000000000000000
# 2.00000000000000 , 2.00000000000000
# 3.00000000000000 , 4.00000000000000
# 4.00000000000000 , 6.00000000000000
# 5.00000000000000 , 8.00000000000000
# 6.00000000000000 , 10.0000000000000
# 7.00000000000000 , 12.0000000000000
# 8.00000000000000 , 14.0000000000000
# 9.00000000000000 , 16.0000000000000
# 10.0000000000000 , 18.0000000000000
# 11.0000000000000 , 20.0000000000000
# 12.0000000000000 , 22.0000000000000
# 13.0000000000000 , 24.0000000000000
# 14.0000000000000 , 26.0000000000000
# 15.0000000000000 , 28.0000000000000
# 16.0000000000000 , 30.0000000000000
# 17.0000000000000 , 32.0000000000000
# 18.0000000000000 , 34.0000000000000
# 19.0000000000000 , 36.0000000000000
# 20.0000000000000 , 38.0000000000000
# 21.0000000000000 , 40.0000000000000
# 22.0000000000000 , 42.0000000000000
# 23.0000000000000 , 44.0000000000000
# 24.0000000000000 , 46.0000000000000
# 25.0000000000000 , 48.0000000000000
# 26.0000000000000 , 50.0000000000000
# ...
